# %% [markdown]
# 클러스터링
# ==
# 데이터
# --
# #### 2020/ 04 / 30 keonwooPark
# #### 항공사별 데이터 클러스터링

# %% [markdown]
# 필요한 라이브러리(모듈) 설치
# --

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 데이터 읽기
# --

# %%
power_data = pd.read_excel('항공사별_통계2.xlsx')
print(power_data.shape)
# Out:
# (34, 13)

# %%
power_data
# Out:
#    항공사별(1)  1월운항도착  1월운항출발  1월여객도착  1월여객출발  1월화물도착   1월화물출발  2월운항도착  2월운항출발  \
# 0      AAR    3060    3066  560278  560154  7024.8   7261.4    2429    2430
# 1      AAV      27      27    3350    3220    36.4     31.2      20      20
# 2      ABL    3058    3062  505813  503372  3573.5   3496.3    2418    2409
# 3      ANA      93      93   14866   17740   179.4    745.1      87      87
# 4      APG      18      18    2575    2449    23.9     20.2      17      17
# 5      ASV     222     222   46127   46127   201.0    201.0     196     196
# 6      BAV       4       5     621     637     9.6     10.7       4       3
# 7      CAL      76      76   11449   11144   152.9    184.9      56      56
# 8      CCA      62      62    8778    7672   120.4    141.5      20      21
# 9      CES     177     177   23421   23023   347.2    395.4      42      42
# 10     CQH     280     281   41030   41753   277.2    455.8      19      22
# 11     CSH      70      69   11973    9652   222.4    167.2      16      16
# 12     CSN     106     106   12397   12371   149.0    206.8      21      21
# 13     DKH      75      75    9895    9838    89.9    196.7      16      16
# 14     ESR    1722    1725  307791  306453  1532.8   1505.2    1325    1321
# 15     EVA      18      18    3159    3132    36.9     50.8      14      14
# 16     FGW     193     193   20165   20226   124.7    130.9     176     176
# 17     HAD      40      40    4895    4126    91.1     70.4      15      15
# 18     HKE      22      22    3551    3353    27.5     40.0      16      16
# 19     HVN      94      95   21382   23643   441.6    938.6      74      71
# 20     JAL     155     155   23361   27984   402.4   1033.8     145     145
# 21     JJA    3167    3169  548413  546951  2920.8   2863.9    2227    2222
# 22     JNA    1709    1713  292176  292143  2131.1   2116.5    1010    1005
# 23     KAL    4690    4694  677892  674363  9819.4  10164.7    3822    3821
# 24     MGL       9       9    1056     911    18.1     16.8       7       7
# 25     PAL      42      42    7685    7947   120.3    273.6      33      33
# 26     SHU      32      32    3418    3189    38.1     40.9      29      29
# 27     SIA      17      17    3874    4044    60.6    102.3      16      16
# 28     SWM      27      29    3213    3330    31.5     29.8      12      10
# 29     THA      27      27    6742    6825   279.4    240.6      22      22
# 30     TTW      49      49    7858    6968    69.0     70.6      40      40
# 31     TWB    1987    1993  333341  334285  2181.5   2157.5    1462    1455
# 32     VJC     106     107   19685   19562   208.0    223.6      81      79
# 33     XAX      48      48   14179   15181   168.2    261.6      46      46
#
#     2월여객도착  2월여객출발  2월화물도착  2월화물출발
# 0   317012  319349  4462.7  4877.6
# 1     1500    1330    17.2    13.8
# 2   235307  231682  1609.3  1595.2
# 3    11608   11657   152.7   626.8
# 4     1966    1400    18.7    12.0
# 5    31233   31233   117.0   117.0
# 6      262     247     4.8     4.7
# 7     4281    5156    67.3    96.7
# 8      927    1394    18.0    43.0
# 9     2038    4089    48.7   120.8
# 10     860    2586     7.2    30.9
# 11     988    1313    24.2    56.4
# 12    1573    1536    23.1    43.3
# 13     880    1609     8.8    34.2
# 14  190851  190311   695.1   696.3
# 15    1300    1532    16.7    28.8
# 16    8716    9235    48.9    57.3
# 17     857    1266    27.3    22.1
# 18    1135    1665    11.0    22.3
# 19   12625    9898   372.7   542.1
# 20   21064   20896   368.3   773.5
# 21  288666  281205  1348.2  1303.1
# 22  115189  109967   903.8   826.5
# 23  381054  381690  6145.3  6667.4
# 24     531     838     9.2    16.8
# 25    5123    4702    99.4   178.1
# 26    2658    2331    32.3    31.9
# 27    1776    1592    66.5    89.0
# 28     953     528    10.2     5.8
# 29    3260    2435   264.9   213.7
# 30    2306    3355    21.7    44.1
# 31  180319  175272  1009.1   951.1
# 32   10615    8884   162.8   110.9
# 33    8474    7717   100.6   172.9

# %%
power = power_data.set_index('항공사별(1)')

# %%
power.head()
# Out:
#          1월운항도착  1월운항출발  1월여객도착  1월여객출발  1월화물도착  1월화물출발  2월운항도착  2월운항출발  \
# 항공사별(1)
# AAR        3060    3066  560278  560154  7024.8  7261.4    2429    2430
# AAV          27      27    3350    3220    36.4    31.2      20      20
# ABL        3058    3062  505813  503372  3573.5  3496.3    2418    2409
# ANA          93      93   14866   17740   179.4   745.1      87      87
# APG          18      18    2575    2449    23.9    20.2      17      17
#
#          2월여객도착  2월여객출발  2월화물도착  2월화물출발
# 항공사별(1)
# AAR      317012  319349  4462.7  4877.6
# AAV        1500    1330    17.2    13.8
# ABL      235307  231682  1609.3  1595.2
# ANA       11608   11657   152.7   626.8
# APG        1966    1400    18.7    12.0

# %% [markdown]
# 한글 폰트 설정 (맥, 윈도우, 리눅스)
# --

# %%
import platform
import matplotlib
from matplotlib import font_manager, rc

# '-' 기호 보이게 하기
matplotlib.rcParams['axes.unicode_minus'] = False

# 운영 체제마다 한글이 보이게 하는 설정
# 윈도우
if platform.system() == 'Windows':
    path = "c:\Windows\Fonts\malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
# 맥
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
# 리눅스
elif platform.system() == 'Linux':
    rc('font', family='NanumBarunGothic')

# %%
power = power.drop(['AAR','ABL','ESR','JJA','JNA','KAL','TWB','ASV','CES','CQH','FGW','JAL'])

# %%
see2 = [ '1월운항출발','1월화물출발']
power[see2].plot(kind='barh', figsize=(10,6), stacked=True)

# %%
power = power[['1월운항출발','1월화물출발']]
power.head(5)
# Out:
#          1월운항출발  1월화물출발
# 항공사별(1)
# AAV          27    31.2
# ANA          93   745.1
# APG          18    20.2
# BAV           5    10.7
# CAL          76   184.9

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['1월운항출발'], power['1월화물출발'],c='k',marker='o')
plt.xlabel('1월운항출발')
plt.ylabel('1월화물출발')

for n in range(power.shape[0]):
    plt.text(power['1월운항출발'][n]*1.03, power['1월화물출발'][n]*0.98, power.index[n])

# %% [markdown]
# 스캐터 플롯
# --

# %% [markdown]
# 덴드로그램
# --

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

plt.figure(figsize=(10, 5))
link_dist = linkage(power, metric='euclidean', method='ward')  
dendrogram(link_dist, labels=power.index)
plt.show()

# %% [markdown]
# 클러스터링 (KMeans)
# --

# %%
from sklearn.cluster import KMeans
k = KMeans(n_clusters=3).fit(power)
print(k.n_clusters)
# Out:
# 3

# %%
power['클러스터'] = k.labels_
power.head(10)
# Out:
#          1월운항출발  1월화물출발  클러스터
# 항공사별(1)
# AAV          27    31.2     1
# ANA          93   745.1     0
# APG          18    20.2     1
# BAV           5    10.7     1
# CAL          76   184.9     2
# CCA          62   141.5     2
# CSH          69   167.2     2
# CSN         106   206.8     2
# DKH          75   196.7     2
# EVA          18    50.8     1

# %%
power.drop('클러스터', axis = 1, inplace=True) ; power.head()
# Out:
#          1월운항출발  1월화물출발
# 항공사별(1)
# AAV          27    31.2
# ANA          93   745.1
# APG          18    20.2
# BAV           5    10.7
# CAL          76   184.9

# %%
centers = k.cluster_centers_ ; centers
# Out:
# array([[ 68.        , 210.72222222],
#        [ 94.        , 841.85      ],
#        [ 24.18181818,  43.97272727]])

# %%
my_markers=['*','^', 'o','^','.',',','1','2']
my_color =['r','c','g','b','g','k','r','y']

plt.figure(figsize=(10, 8))
plt.xlabel('1월운항출발')
plt.ylabel('1월화물출발')
for n in range(power.shape[0]):
    label = k.labels_[n]
    plt.scatter(power['1월운항출발'][n], power['1월화물출발'][n], c=my_color[label], marker=my_markers[label], s=100)
    plt.text(power['1월운항출발'][n]*1.03, power['1월화물출발'][n]*0.98, power.index[n])
    
for i in range(k.n_clusters):
    plt.scatter(centers[i][0], centers[i][1], c = 'y', s= 50)

# %% [markdown]
# 스케일링 (표준 정규화)
# --

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
power[['1월운항출발', '1월화물출발']] = scaler.fit_transform(power[['1월운항출발', '1월화물출발']])
power
# Out:
#            1월운항출발    1월화물출발
# 항공사별(1)
# AAV     -0.684207 -0.677647
# ANA      1.420600  2.473496
# APG     -0.971227 -0.726201
# BAV     -1.385810 -0.768134
# CAL      0.878453  0.000782
# CCA      0.431978 -0.190784
# CSH      0.655216 -0.077345
# CSN      1.835184  0.097449
# DKH      0.846562  0.052867
# EVA     -0.971227 -0.591133
# HAD     -0.269624 -0.504619
# HKE     -0.843663 -0.638804
# HVN      1.484382  3.327602
# MGL     -1.258246 -0.741208
# PAL     -0.205842  0.392303
# SHU     -0.524752 -0.634831
# SIA     -1.003118 -0.363813
# SWM     -0.620425 -0.683826
# THA     -0.684207  0.246641
# TTW      0.017395 -0.503736
# VJC      1.867075  0.171604
# XAX     -0.014496  0.339335

# %% [markdown]
# 정규화 이후의 클러스터링
# --

# %%
Z = linkage(power, metric='euclidean', method='ward') 
# 유클리드 거리를 이용해 Linkage Matrix를 생성
plt.figure(figsize=(10, 5))
plt.title('덴드로그램')
dendrogram(Z, labels=power.index)
plt.show()

# %%
k = KMeans(n_clusters= 5).fit(power)

# %%
centers = k.cluster_centers_

# %%
plt.clf()
plt.figure(figsize=(10, 8))
plt.xlabel('1월운항출발')
plt.ylabel('1월화물출발')

for n in range(power.shape[0]):
    label = k.labels_[n]
    plt.scatter(power['1월운항출발'][n], power['1월화물출발'][n], c=my_color[label], marker=my_markers[label], s=100)
    plt.text(power['1월운항출발'][n]*1.05, power['1월화물출발'][n]*0.99, power.index[n])
    
for i in range(k.n_clusters):
    plt.scatter(centers[i][0], centers[i][1], c = 'y', s= 50)

# %% [markdown]
# 모든 특성을 고려한 크러스터링 (두개가 아니라)
# --

# %%
power_data.head()
# Out:
#   항공사별(1)  1월운항도착  1월운항출발  1월여객도착  1월여객출발  1월화물도착  1월화물출발  2월운항도착  2월운항출발  \
# 0     AAR    3060    3066  560278  560154  7024.8  7261.4    2429    2430
# 1     AAV      27      27    3350    3220    36.4    31.2      20      20
# 2     ABL    3058    3062  505813  503372  3573.5  3496.3    2418    2409
# 3     ANA      93      93   14866   17740   179.4   745.1      87      87
# 4     APG      18      18    2575    2449    23.9    20.2      17      17
#
#    2월여객도착  2월여객출발  2월화물도착  2월화물출발
# 0  317012  319349  4462.7  4877.6
# 1    1500    1330    17.2    13.8
# 2  235307  231682  1609.3  1595.2
# 3   11608   11657   152.7   626.8
# 4    1966    1400    18.7    12.0

# %%
power2 = power_data.set_index('항공사별(1)')
power2 = power2.drop(['AAR','ABL','ESR','JJA','JNA','KAL','TWB','ASV','CES','CQH','FGW','JAL'])
#power2.drop(['업무용합계', '산업용합계', '합계'], axis=1, 
 #          inplace=True, errors='ignore')
#power2.drop(['합계','개성','경기','서울'], inplace=True,errors='ignore')

# %%
power2.head()
# Out:
#          1월운항도착  1월운항출발  1월여객도착  1월여객출발  1월화물도착  1월화물출발  2월운항도착  2월운항출발  \
# 항공사별(1)
# AAV          27      27    3350    3220    36.4    31.2      20      20
# ANA          93      93   14866   17740   179.4   745.1      87      87
# APG          18      18    2575    2449    23.9    20.2      17      17
# BAV           4       5     621     637     9.6    10.7       4       3
# CAL          76      76   11449   11144   152.9   184.9      56      56
#
#          2월여객도착  2월여객출발  2월화물도착  2월화물출발
# 항공사별(1)
# AAV        1500    1330    17.2    13.8
# ANA       11608   11657   152.7   626.8
# APG        1966    1400    18.7    12.0
# BAV         262     247     4.8     4.7
# CAL        4281    5156    67.3    96.7

# %%
index_power = power2.index
column_power = power2.columns
manufacture = list(column_power).index('1월운항출발')
service = list(column_power).index('1월화물출발')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# 이제 power3는 ndarray이다
power3 = scaler.fit_transform(power2)

# %%
type(power3);type(power2)
# Out:
# pandas.core.frame.DataFrame

# %%
Z = linkage(power3, metric='euclidean', method='ward') 
# 유클리드 거리를 이용해 Linkage Matrix를 생성
plt.figure(figsize=(10, 5))
plt.title('덴드로그램')
dendrogram(Z, labels=index_power)
plt.show()

# %%
k = KMeans(n_clusters=4).fit(power3)

# %%
n_samples = power3.shape[0]
print(n_samples)

plt.figure(figsize=(10, 8))
plt.xlabel('1월운항출발')
plt.ylabel('1월화물출발')

for n in range(n_samples):
    label = k.labels_[n]
    plt.scatter(power3[n][service], power3[n][manufacture], c=my_color[label], marker=my_markers[label], s=100)
    plt.text(power3[n][service]*1.05, power3[n][manufacture]*0.99, index_power[n])
# Out:
# 22

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
X, y = make_moons(n_samples=300, noise=0.05, random_state=11)
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
predict = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.2, min_samples=10, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)
